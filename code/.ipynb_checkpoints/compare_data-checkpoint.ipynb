# %% [markdown]
# # Goal: Compare downloaded GISAID data and Github data
#
#
# Data:
#
#     1.   Data directly downloaded from GISAID
#     2.   Data take from blab github repo (https://github.com/blab/ncov-ny/tree/master/data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

#importing github data 
gh_md = pd.read_csv("https://raw.githubusercontent.com/blab/ncov-ny/master/data/ny_metadata.tsv", sep = "\t")
# gh_md.head()
gh_md.dropna().head()
# Out:
#                      strain        date         region country  division  \
# 101  USA/CUIMC-NP-5080/2021  2021-02-04  North America     USA  New York
# 168     USA/NY-NP-3005/2020  2020-08-24  North America     USA  New York
# 170     USA/NY-NP-3581/2020  2020-11-30  North America     USA  New York
# 171     USA/NY-NP-3698/2020  2020-12-05  North America     USA  New York
# 172     USA/NY-NP-3840/2020  2020-12-11  North America     USA  New York
#
#           location pango_lineage gisaid_accession
# 101  New York City       B.1.351  EPI_ISL_1001460
# 168  New York City           B.1  EPI_ISL_1080797
# 170  New York City       B.1.526  EPI_ISL_1080752
# 171  New York City       B.1.526  EPI_ISL_1080765
# 172  New York City       B.1.526  EPI_ISL_1080798

# %% [markdown]
# ## Importing metadata from gisaid

# %%
#importing metadata from gisaid
gs_md = pd.read_csv("../data/nyc/gisaid_nyc_metadata.tsv",sep = "\t")
print(len(gs_md.strain)," columns")
gs_md.head()
# Out:
# 2491  columns
#                                      strain            virus   gisaid_epi_isl  \
# 0  hCoV-19/USA/NY-PRL-2021_02_05_08B05/2021  betacoronavirus  EPI_ISL_1041215
# 1  hCoV-19/USA/NY-PRL-2021_02_05_08D12/2021  betacoronavirus  EPI_ISL_1041222
# 2  hCoV-19/USA/NY-PRL-2021_02_05_08E02/2021  betacoronavirus  EPI_ISL_1041223
# 3  hCoV-19/USA/NY-PRL-2021_02_05_08F02/2021  betacoronavirus  EPI_ISL_1041226
# 4  hCoV-19/USA/NY-PRL-2021_02_05_08F09/2021  betacoronavirus  EPI_ISL_1041227
#
#   genbank_accession        date         region country  division  \
# 0                 ?  2021-02-03  North America     USA  New York
# 1                 ?  2021-02-03  North America     USA  New York
# 2                 ?  2021-02-04  North America     USA  New York
# 3                 ?  2021-02-03  North America     USA  New York
# 4                 ?  2021-02-03  North America     USA  New York
#
#         location region_exposure  ... pangolin_lineage GISAID_clade  \
# ...

# %%
figure(figsize=(15, 12), dpi=80)
# plt.hist(gh_md.pango_lineage)
plt.hist(gs_md.date)
# plt.xticks(rotation=45)
# Out:
# (array([333., 174.,  73.,  32., 332., 408., 193., 538., 389.,  19.]),
#  array([ 0. ,  7.6, 15.2, 22.8, 30.4, 38. , 45.6, 53.2, 60.8, 68.4, 76. ]),
#  <BarContainer object of 10 artists>)

# %%
print(len(gh_md.gisaid_accession))
gh_md.gisaid_accession.isna().sum()
# Out:
# 233
# 184
